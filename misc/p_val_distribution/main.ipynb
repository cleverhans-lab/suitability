# %% [markdown]
# ### This is an R notebook

# %%
if (!require("TeachingDemos")) {
  install.packages("TeachingDemos")
}
library(TeachingDemos)
# Out:
# Loading required package: TeachingDemos

# %%
set.seed(123)

# %% [markdown]
# ## When null is true

# %%
# Do 3 subplots next to each other
Pvalue.norm.sim(mu = 0, mu0=0, alternative = "two.sided")
# Out:
# Plot with title “”

# %%
Pvalue.norm.sim(mu = 0, mu0=0, alternative = "greater")
# Out:
# Plot with title “”

# %%
Pvalue.norm.sim(mu = 0, mu0=0, alternative = "less")
# Out:
# Plot with title “”

# %% [markdown]
# ## When null is false

# %%
Pvalue.norm.sim(mu = 1, mu0=0, alternative = "two.sided")
Pvalue.norm.sim(mu = 1, mu0=0, alternative = "greater")
Pvalue.norm.sim(mu = 1, mu0=0, alternative = "less")
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
